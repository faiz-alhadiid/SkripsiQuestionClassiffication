# %%
import pandas as pd
import json

# %%
c_list = [0.5, 1, 1.5, 2, 2.5, 3]
max_iter_list = [250, 500, 750, 1000, 1500, 2000]
tol_list = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5]

# %%
# Pengujian C

max_iter = 500
tol = 0.001

df = pd.DataFrame(columns=['C','Fold', 'Accuracy', 'Precision', 'Recall', 'F Measure'])
for c in c_list:
    for i in range(5):
        file_name = f"output/C_{c}-tol_{tol}-max_iter_{max_iter}-fold_{i}.json"
        f = open(file_name, 'r')
        json_file = json.loads(f.read())
        evaluation = json_file['evaluation']
        df = df.append({
            'C': c, 
            'Fold': i+1, 
            'Accuracy': evaluation['accuracy'],
            'Precision': evaluation['avg_precision'],
            'Recall': evaluation['avg_recall'],
            'F Measure': evaluation['avg_f_measure']
        }, ignore_index=True)


df.to_csv('csv_coarse/pengujian_c.csv', sep=';', index=False)
df
# Out:
#       C  Fold  Accuracy  Precision    Recall  F Measure
# 0   0.5   1.0  0.798535   0.829825  0.755648   0.778045
# 1   0.5   2.0  0.786517   0.761073  0.774880   0.758438
# 2   0.5   3.0  0.823970   0.854448  0.774911   0.800604
# 3   0.5   4.0  0.791667   0.784036  0.746726   0.761410
# 4   0.5   5.0  0.826255   0.872786  0.793537   0.818306
# 5   1.0   1.0  0.809524   0.833419  0.807369   0.815316
# 6   1.0   2.0  0.794007   0.761947  0.778666   0.762032
# 7   1.0   3.0  0.838951   0.867555  0.788495   0.813394
# 8   1.0   4.0  0.780303   0.745638  0.700615   0.714948
# 9   1.0   5.0  0.826255   0.867975  0.849217   0.850206
# 10  1.5   1.0  0.805861   0.831420  0.803367   0.813017
# 11  1.5   2.0  0.797753   0.797827  0.773365   0.775446
# 12  1.5   3.0  0.823970   0.852105  0.777835   0.800323
# 13  1.5   4.0  0.780303   0.743347  0.700994   0.714402
# 14  1.5   5.0  0.837838   0.872808  0.857426   0.857851
# 15  2.0   1.0  0.794872   0.823078  0.793276   0.803202
# 16  2.0   2.0  0.797753   0.797827  0.773365   0.775446
# 17  2.0   3.0  0.816479   0.846803  0.770259   0.793820
# 18  2.0   4.0  0.780303   0.743347  0.700994   0.714402
# 19  2.0   5.0  0.833977   0.871664  0.853259   0.855164
# 20  2.5   1.0  0.794872   0.823078  0.793276   0.803202
# 21  2.5   2.0  0.797753   0.797827  0.773365   0.775446
# 22  2.5   3.0  0.816479   0.846803  0.770259   0.793820
# 23  2.5   4.0  0.780303   0.743347  0.700994   0.714402
# 24  2.5   5.0  0.833977   0.871664  0.853259   0.855164
# 25  3.0   1.0  0.794872   0.823078  0.793276   0.803202
# 26  3.0   2.0  0.797753   0.797827  0.773365   0.775446
# 27  3.0   3.0  0.816479   0.846803  0.770259   0.793820
# 28  3.0   4.0  0.780303   0.743347  0.700994   0.714402
# 29  3.0   5.0  0.833977   0.871664  0.853259   0.855164

# %%
# Rata Rata Fold nilai C
max_iter = 500
tol = 0.001

df = pd.DataFrame(columns=['C','Fold', 'Accuracy', 'Precision', 'Recall', 'F Measure'])
for c in c_list:
    file_name = f"output/AVG_C_{c}-tol_{tol}-max_iter_{max_iter}.json"
    f = open(file_name, 'r')
    json_file = json.loads(f.read())
    evaluation = json_file['evaluation']
    df = df.append({
        'C': c, 
        'Fold': i+1, 
        'Accuracy': evaluation['accuracy'],
        'Precision': evaluation['avg_precision'],
        'Recall': evaluation['avg_recall'],
        'F Measure': evaluation['avg_f_measure']
    }, ignore_index=True)

df.to_csv('csv_coarse/pengujian_c-avg.csv', sep=';', index=False)
df
# Out:
#      C  Fold  Accuracy  Precision    Recall  F Measure
# 0  0.5   5.0  0.805389   0.820434  0.769140   0.783360
# 1  1.0   5.0  0.809808   0.815307  0.784872   0.791179
# 2  1.5   5.0  0.809145   0.819501  0.782597   0.792208
# 3  2.0   5.0  0.804677   0.816544  0.778230   0.788407
# 4  2.5   5.0  0.804677   0.816544  0.778230   0.788407
# 5  3.0   5.0  0.804677   0.816544  0.778230   0.788407

# %%
# Pengujian max_iter

c = 1
max_iter_list = [250, 500, 750, 1000, 1500, 2000]
tol = 0.001

df = pd.DataFrame(columns=['Max Iter', 'Fold','Accuracy', 'Precision', 'Recall', 'F Measure'])
for max_iter in max_iter_list:
    for i in range(5):
        file_name = f"output/C_{c}-tol_{tol}-max_iter_{max_iter}-fold_{i}.json"
        f = open(file_name, 'r')
        json_file = json.loads(f.read())
        evaluation = json_file['evaluation']
        df = df.append({
            'Max Iter': max_iter,
            'Fold': i+1,
            'Accuracy': evaluation['accuracy'],
            'Precision': evaluation['avg_precision'],
            'Recall': evaluation['avg_recall'],
            'F Measure': evaluation['avg_f_measure']
        }, ignore_index=True)

df.to_csv('csv_coarse/pengujian_max_iter.csv', sep=';', index=False)
df
# Out:
#     Max Iter  Fold  Accuracy  Precision    Recall  F Measure
# 0      250.0   1.0  0.809524   0.844310  0.833542   0.837634
# 1      250.0   2.0  0.782772   0.748624  0.769462   0.748326
# 2      250.0   3.0  0.812734   0.845236  0.762088   0.789432
# 3      250.0   4.0  0.791667   0.784145  0.749214   0.761640
# 4      250.0   5.0  0.787645   0.832357  0.765431   0.789575
# 5      500.0   1.0  0.809524   0.833419  0.807369   0.815316
# 6      500.0   2.0  0.794007   0.761947  0.778666   0.762032
# 7      500.0   3.0  0.838951   0.867555  0.788495   0.813394
# 8      500.0   4.0  0.780303   0.745638  0.700615   0.714948
# 9      500.0   5.0  0.826255   0.867975  0.849217   0.850206
# 10     750.0   1.0  0.809524   0.835761  0.804017   0.815013
# 11     750.0   2.0  0.790262   0.771686  0.772875   0.762197
# 12     750.0   3.0  0.827715   0.856666  0.778162   0.803069
# 13     750.0   4.0  0.780303   0.773727  0.737307   0.752325
# 14     750.0   5.0  0.849421   0.888187  0.867464   0.872370
# 15    1000.0   1.0  0.816850   0.841383  0.810720   0.821975
# 16    1000.0   2.0  0.801498   0.777849  0.784997   0.770774
# 17    1000.0   3.0  0.823970   0.852828  0.775289   0.799788
# 18    1000.0   4.0  0.784091   0.776103  0.740716   0.755346
# 19    1000.0   5.0  0.830116   0.870733  0.851470   0.852854
# 20    1500.0   1.0  0.816850   0.842149  0.811807   0.822371
# 21    1500.0   2.0  0.797753   0.771821  0.782453   0.767457
# 22    1500.0   3.0  0.823970   0.852522  0.775125   0.799486
# 23    1500.0   4.0  0.795455   0.790843  0.747383   0.765343
# 24    1500.0   5.0  0.837838   0.877009  0.857426   0.860031
# 25    2000.0   1.0  0.816850   0.842042  0.811428   0.822361
# 26    2000.0   2.0  0.797753   0.773288  0.780451   0.767139
# 27    2000.0   3.0  0.823970   0.853026  0.775833   0.799972
# 28    2000.0   4.0  0.795455   0.790843  0.747383   0.765343
# 29    2000.0   5.0  0.833977   0.873230  0.855173   0.856775

# %%
# rata_rata max_iter

c = 1
max_iter_list = [250, 500, 750, 1000, 1500, 2000]
tol = 0.001

df = pd.DataFrame(columns=['Max Iter', 'Accuracy', 'Precision', 'Recall', 'F Measure'])
for max_iter in max_iter_list:
    file_name = f"output/AVG_C_{c}-tol_{tol}-max_iter_{max_iter}.json"
    f = open(file_name, 'r')
    json_file = json.loads(f.read())
    evaluation = json_file['evaluation']
    df = df.append({
        'Max Iter': max_iter, 
        'Accuracy': evaluation['accuracy'],
        'Precision': evaluation['avg_precision'],
        'Recall': evaluation['avg_recall'],
        'F Measure': evaluation['avg_f_measure']
    }, ignore_index=True)


df.to_csv('csv_coarse/pengujian_max_iter_avg.csv', sep=';', index=False)
df
# Out:
#    Max Iter  Accuracy  Precision    Recall  F Measure
# 0     250.0  0.796868   0.810934  0.775947   0.785321
# 1     500.0  0.809808   0.815307  0.784872   0.791179
# 2     750.0  0.811445   0.825206  0.791965   0.800995
# 3    1000.0  0.811305   0.823779  0.792638   0.800147
# 4    1500.0  0.814373   0.826869  0.794839   0.802938
# 5    2000.0  0.813601   0.826486  0.794054   0.802318

# %%
# Pengujian tol

c = 1
max_iter = 1500
tol_list = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5]

df = pd.DataFrame(columns=['Tol', 'Fold','Accuracy', 'Precision', 'Recall', 'F Measure'])
for tol in tol_list:
    for i in range(5):
        file_name = f"output/C_{c}-tol_{tol}-max_iter_{max_iter}-fold_{i}.json"
        f = open(file_name, 'r')
        json_file = json.loads(f.read())
        evaluation = json_file['evaluation']
        df = df.append({
            'Tol': tol,
            'Fold': i+1,
            'Accuracy': evaluation['accuracy'],
            'Precision': evaluation['avg_precision'],
            'Recall': evaluation['avg_recall'],
            'F Measure': evaluation['avg_f_measure']
        }, ignore_index=True)

df.to_csv('csv_coarse/pengujian_tol.csv', sep=';', index=False)
df
# Out:
#        Tol  Fold  Accuracy  Precision    Recall  F Measure
# 0   0.0001   1.0  0.816850   0.842149  0.811807   0.822371
# 1   0.0001   2.0  0.797753   0.771821  0.782453   0.767457
# 2   0.0001   3.0  0.823970   0.852522  0.775125   0.799486
# 3   0.0001   4.0  0.795455   0.790843  0.747383   0.765343
# 4   0.0001   5.0  0.837838   0.877009  0.857426   0.860031
# 5   0.0005   1.0  0.816850   0.842149  0.811807   0.822371
# 6   0.0005   2.0  0.797753   0.771821  0.782453   0.767457
# 7   0.0005   3.0  0.823970   0.852522  0.775125   0.799486
# 8   0.0005   4.0  0.795455   0.790843  0.747383   0.765343
# 9   0.0005   5.0  0.837838   0.877009  0.857426   0.860031
# 10  0.0010   1.0  0.816850   0.842149  0.811807   0.822371
# 11  0.0010   2.0  0.797753   0.771821  0.782453   0.767457
# 12  0.0010   3.0  0.823970   0.852522  0.775125   0.799486
# 13  0.0010   4.0  0.795455   0.790843  0.747383   0.765343
# 14  0.0010   5.0  0.837838   0.877009  0.857426   0.860031
# 15  0.0050   1.0  0.816850   0.842149  0.811807   0.822371
# 16  0.0050   2.0  0.797753   0.771821  0.782453   0.767457
# 17  0.0050   3.0  0.823970   0.852522  0.775125   0.799486
# 18  0.0050   4.0  0.795455   0.790843  0.747383   0.765343
# 19  0.0050   5.0  0.837838   0.877009  0.857426   0.860031
# 20  0.0100   1.0  0.816850   0.842149  0.811807   0.822371
# 21  0.0100   2.0  0.797753   0.771821  0.782453   0.767457
# 22  0.0100   3.0  0.823970   0.852522  0.775125   0.799486
# 23  0.0100   4.0  0.795455   0.790843  0.747383   0.765343
# 24  0.0100   5.0  0.837838   0.877009  0.857426   0.860031
# 25  0.0500   1.0  0.816850   0.842149  0.811807   0.822371
# 26  0.0500   2.0  0.797753   0.771821  0.782453   0.767457
# 27  0.0500   3.0  0.823970   0.852522  0.775125   0.799486
# 28  0.0500   4.0  0.795455   0.790843  0.747383   0.765343
# 29  0.0500   5.0  0.837838   0.877009  0.857426   0.860031
# 30  0.1000   1.0  0.809524   0.835835  0.806047   0.815900
# 31  0.1000   2.0  0.797753   0.771821  0.782453   0.767457
# 32  0.1000   3.0  0.823970   0.852522  0.775125   0.799486
# 33  0.1000   4.0  0.795455   0.790843  0.747383   0.765343
# 34  0.1000   5.0  0.837838   0.877009  0.857426   0.860031
# 35  0.5000   1.0  0.813187   0.839094  0.808184   0.818716
# 36  0.5000   2.0  0.797753   0.773521  0.780830   0.766921
# 37  0.5000   3.0  0.820225   0.850431  0.772424   0.796649
# 38  0.5000   4.0  0.784091   0.753187  0.702672   0.719622
# 39  0.5000   5.0  0.837838   0.876049  0.857426   0.859438

# %%
# rata_rata tol

c = 1
max_iter = 1500
tol_list = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5]

df = pd.DataFrame(columns=['Tol', 'Accuracy', 'Precision', 'Recall', 'F Measure'])
for tol in tol_list:
    file_name = f"output/AVG_C_{c}-tol_{tol}-max_iter_{max_iter}.json"
    f = open(file_name, 'r')
    json_file = json.loads(f.read())
    evaluation = json_file['evaluation']
    df = df.append({
        'Tol': tol, 
        'Accuracy': evaluation['accuracy'],
        'Precision': evaluation['avg_precision'],
        'Recall': evaluation['avg_recall'],
        'F Measure': evaluation['avg_f_measure']
    }, ignore_index=True)

df.to_csv('csv_coarse/pengujian_tol_avg.csv', sep=';', index=False)
df
# Out:
#       Tol  Accuracy  Precision    Recall  F Measure
# 0  0.0001  0.814373   0.826869  0.794839   0.802938
# 1  0.0005  0.814373   0.826869  0.794839   0.802938
# 2  0.0010  0.814373   0.826869  0.794839   0.802938
# 3  0.0050  0.814373   0.826869  0.794839   0.802938
# 4  0.0100  0.814373   0.826869  0.794839   0.802938
# 5  0.0500  0.814373   0.826869  0.794839   0.802938
# 6  0.1000  0.812908   0.825606  0.793687   0.801643
# 7  0.5000  0.810619   0.818457  0.784307   0.792269
